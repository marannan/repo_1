# %%
import numpy as np
import pandas as pd

cols = ["EIN", "NAME", "SUBSECCD", "ACTIV1", "ACTIV2", "ACTIV3", "GRRECMEM",
        "GRRECOTH", "ASS_EOY", "NETINC", "TOTREV", "ZIP", "zip5"]

df = pd.read_csv('../data/core_other/core_other_2013.txt',
                 usecols=cols, low_memory=False)

sec_ids = [1, 12, 14, 15, 16, 50, 60, 80]

orgs = df[df.SUBSECCD.isin(sec_ids)]

zip_codes = pd.read_csv('../data/zipcodes/zip_codes.csv')

merged = orgs.merge(zip_codes, left_on="zip5", right_on="Zipcode")

pd.__version__
# Out:
# '0.17.1'

# %%
grouped = merged[["SUBSECCD", "ASS_EOY", "TOTREV", "NETINC"]].groupby(['SUBSECCD'])
x = grouped.agg(['size','mean', 'median', 'sum'])
x
# Out:
#          ASS_EOY                                    TOTREV                     \
#             size       mean    median           sum   size      mean   median
# SUBSECCD
# 1             24   22312705  16571547     535504941     24   1148354   839547
# 12          3796   37583939   1689259  142668635275   3796  16369872   383409
# 14          2217  188866714  34003673  418717505200   2217   8760157  1502512
# 15           249    1243840    921046     309716223    249    274216   266298
# 16             9   55175240  30612400     496577163      9   2491226  2004236
#
#                       NETINC
#                   sum   size            mean    median         sum
# SUBSECCD
# 1            27560500     24    91681.583333   10729.0     2200358
# 12        62140036887   3796   423454.789515    7072.5  1607434381
# 14        19421268634   2217  1448567.312134   78416.0  3211473731
# 15           68279810    249    23762.730924   16351.0     5916920
# 16           22421036      9   894659.555556  400088.0     8051936

# %%
df = merged[merged.SUBSECCD == 16]
df[['NAME', 'SUBSECCD', 'ASS_EOY', 'TOTREV']]
# Out:
#                                              NAME  SUBSECCD    ASS_EOY  \
# 463           EQUITY LIVESTOCK CREDIT CORPORATION        16    4639659
# 772            NATIONAL FINANCE CREDIT CORP OF TX        16  133274669
# 1233            EDMONSON CO CATTLEMEN ASSOCIATION        16      63494
# 2313                 PRODUCERS LIVE STOCK CR CORP        16  119575828
# 3384              TRI-STATE LIVESTOCK CREDIT CORP        16   30612400
# 3519  COOPERATIVA DE AHORRO Y CREDITO DE MAYAGUEZ        16   92849988
# 5700           STAPLE COTTON DISCOUNT CORPORATION        16  108210390
# 6055             PRODUCERS LIVESTOCK CREDIT ASSOC        16    6892831
# 6249                     VETERANS OF FOREIGN WARS        16     457904
#
#        TOTREV
# 463    227514
# 772   5853304
# 1233    73802
# 2313  5180480
# 3384  2004236
# 3519  4978882
# 5700  2747758
# 6055  1206006
# 6249   149054

# %%
df = merged[merged.SUBSECCD == 1]
df[['NAME', 'SUBSECCD', 'ASS_EOY', 'TOTREV']]
# Out:
#                                                    NAME  SUBSECCD   ASS_EOY  \
# 44                                   E S A CREDIT UNION         1   5585006
# 84             MEMBERS ADVANTAGE COMMUMITY CREDIT UNION         1  72078245
# 170                            PAINESVILLE CREDIT UNION         1  25673033
# 222                       FAIRMONT VILLAGE CREDIT UNION         1   1800036
# 523                          ACE COMMUNITY CREDIT UNION         1  32322880
# 528                       LENNOX EMPLOYEES CREDIT UNION         1  33483441
# 530                      FEDERAL EMPLOYEES CREDIT UNION         1  18269368
# 531                                 HUB-CO CREDIT UNION         1  13915877
# 532                 IOWA CORPORATE CENTRAL CREDIT UNION         1  47594283
# 533                                PEOPLES CREDIT UNION         1  20924337
# 539                     DIVISION 6 HIGHWAY CREDIT UNION         1  14873727
# 543               GREATER OZARKS COMMUNITY CREDIT UNION         1   6084726
# 548                         UNITED SAVINGS CREDIT UNION         1  36041397
# 608                      ENTRUST FINANCIAL CREDIT UNION         1  67045994
# 632   CREDIT UNIONS CHARTERED IN THE STATE OF SOUTH ...         1   5938715
# 665   CREDIT UNIONS CHARTERED IN THE STATE OF TENNESSEE         1   5008488
# 678   CREDIT UNIONS CHARTERED IN THE STATE OF TENNESSEE         1   2414701
# 746   CREDIT UNIONS IN THE STATE OF OKLAHOMA ADA FED...         1   8116030
# 752                GOLDEN TRIANGLE FEDERAL CREDIT UNION         1     12750
# 959                BELEN RAILWAY EMPLOYEES CREDIT UNION         1  21937448
# 973                                FREEDOM CREDIT UNION         1  22436791
# 1080                               FARMERS CREDIT UNION         1  13650171
# 3054                             ADVANTAGE CREDIT UNION         1  56851809
# 5712           CREDIT UNIONS IN THE STATE OF NEW MEXICO         1   3445688
#
#        TOTREV
# 44     671471
# 84    3510653
# 170   1438213
# 222    154496
# 523   1291783
# 528   1483849
# 530   1013264
# 531    579191
# 532   2661673
# 533   1068574
# 539    478435
# 543    494334
# 548   1924370
# 608   4177497
# 632    289171
# 665    273665
# 678    130821
# 746    412679
# 752       807
# 959   1007623
# 973   1195248
# 1080   409098
# 3054  2687250
# 5712   206335
